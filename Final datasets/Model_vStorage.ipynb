# %%
# !pip install pyomo
# !apt-get install -y -qq glpk-utils
# Out:
# Requirement already satisfied: pyomo in /usr/local/lib/python3.10/dist-packages (6.6.1)
# Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from pyomo) (3.11)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from pyomo.environ import *

# %% [markdown]
# # **Prediction**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load your DataFrame df
df_storage= pd.read_csv('/content/drive/MyDrive/Capstone Project MMAI/Final Dataset For Model/storage.csv')

# %%
df_storage
# Out:
#    Property Code  2022 Storage Comp price  2023 Storage Comp price  \
# 0         y31201                18.333333                20.000000
# 1         y31202                18.333333                20.000000
# 2         y31251                37.500000                50.000000
# 3         y31300                22.500000                20.000000
# 4         y31600                 0.000000                27.500000
# 5         y31602                 0.000000                36.666667
# 6         y40210                 0.000000                 0.000000
# 7         y40230                 0.000000                50.000000
# 8         y40790                50.000000                 0.000000
# 9         y40910                 0.000000                 0.000000
# 10        y40911                 0.000000                20.000000
# 11        y40940                33.333333                 8.333333
# 12        y40960                33.333333                37.500000
# 13        y41491                 0.000000                31.250000
# 14        y41580                15.000000                 7.500000
# 15        y50121                 0.000000                 0.000000
# 16        y50670                 0.000000                 0.000000
# 17        y50680                32.500000                63.750000
# 18        y52950                52.500000                 0.000000
# 19        y53000                 0.000000                 0.000000
# 20        y53590                 0.000000                 0.000000
# 21        y53600                 0.000000                 0.000000
# 22        y53620                60.000000                 0.000000
# 23        y53630                 0.000000                 0.000000
# 24        y53640                25.000000                50.000000
# 25        y53650                20.000000                13.250000
# 26        y53660                 0.000000                 0.000000
# 27        y55265                 0.000000                 0.000000
# 28        y55270                35.000000                 0.000000
# 29        y55275                35.000000                 0.000000
# 30        y63060                 0.000000                27.500000
# 31        y63070                43.333333                 0.000000
# 32        y63075                 0.000000                 0.000000
# 33        y63130                45.000000                43.333333
# 34        y63135                45.000000                43.333333
# 35        y64170                 0.000000                 0.000000
# 36        y64180                 0.000000                 0.000000
# 37        y65160                 0.000000                 0.000000
# 38        y65165                50.000000                 0.000000
# 39        y65225                60.000000                 0.000000
#
#     Total Units (2022Jul) (Storage)  Occupied (2022Jul) (Storage)  \
# 0                              47.0                          29.0
# 1                              63.0                          47.0
# 2                              70.0                          58.0
# 3                             393.0                         204.0
# 4                             253.0                         143.0
# 5                             215.0                          43.0
# 6                               0.0                           0.0
# 7                               0.0                           0.0
# 8                              60.0                          29.0
# 9                               0.0                           0.0
# 10                              0.0                           0.0
# 11                             49.0                          22.0
# 12                             48.0                          47.0
# 13                            191.0                          39.0
# 14                            169.0                          49.0
# 15                              0.0                           0.0
# 16                              0.0                           0.0
# 17                            241.0                          92.0
# 18                            256.0                         108.0
# 19                              0.0                           0.0
# 20                              0.0                           0.0
# 21                              0.0                           0.0
# 22                             29.0                          24.0
# 23                              0.0                           0.0
# 24                             48.0                          32.0
# 25                            225.0                         177.0
# 26                              0.0                           0.0
# 27                              0.0                           0.0
# 28                              0.0                           0.0
# 29                             26.0                          21.0
# 30                            207.0                         117.0
# 31                              0.0                           0.0
# 32                              0.0                           0.0
# 33                            129.0                          66.0
# 34                             30.0                          30.0
# 35                              0.0                           0.0
# 36                            293.0                          10.0
# 37                            110.0                          77.0
# 38                             64.0                          39.0
# 39                            214.0                         214.0
#
#     Percentage% (2022Jul) (Storage)  New Lease (2022Jul) (Storage)  \
# 0                             61.70                            1.0
# 1                             74.60                            1.0
# 2                             82.86                            1.0
# 3                             51.91                            1.0
# 4                             56.52                            0.0
# 5                             20.00                            1.0
# 6                              0.00                            0.0
# 7                              0.00                            0.0
# 8                             48.33                            6.0
# 9                              0.00                            0.0
# 10                             0.00                            0.0
# 11                            44.90                            0.0
# 12                            97.92                            4.0
# 13                            20.42                            3.0
# 14                            28.99                            1.0
# 15                             0.00                            0.0
# 16                             0.00                            0.0
# 17                            38.17                           10.0
# 18                            42.19                            7.0
# 19                             0.00                            0.0
# 20                             0.00                            0.0
# 21                             0.00                            0.0
# 22                            82.76                            3.0
# 23                             0.00                            0.0
# 24                            66.67                            2.0
# 25                            78.67                           21.0
# 26                             0.00                            0.0
# 27                             0.00                            0.0
# 28                             0.00                            0.0
# 29                            80.77                            0.0
# 30                            56.52                            3.0
# 31                             0.00                            0.0
# 32                             0.00                            0.0
# 33                            51.16                            1.0
# 34                           100.00                            0.0
# 35                             0.00                            0.0
# 36                             3.41                            2.0
# 37                            70.00                            0.0
# 38                            60.94                            3.0
# 39                           100.00                            4.0
#
#     Ending Lease (2022Jul) (Storage)  Market Price (2022Jul) (Storage)  \
# 0                                0.0                              30.0
# 1                                1.0                              25.0
# 2                                3.0                              50.0
# 3                                2.0                              25.0
# 4                                1.0                              25.0
# 5                                0.0                              30.0
# 6                                0.0                               0.0
# 7                                0.0                               0.0
# 8                                6.0                              50.0
# 9                                0.0                               0.0
# 10                               0.0                               0.0
# 11                               3.0                              35.0
# 12                               8.0                              35.0
# 13                              10.0                              25.0
# 14                              10.0                              20.0
# 15                               0.0                               0.0
# 16                               0.0                               0.0
# 17                               9.0                              25.0
# 18                              12.0                              40.0
# 19                               0.0                               0.0
# 20                               0.0                               0.0
# 21                               0.0                               0.0
# 22                               1.0                              25.0
# 23                               0.0                               0.0
# 24                               1.0                              30.0
# 25                              42.0                              20.0
# 26                               0.0                               0.0
# 27                               0.0                               0.0
# 28                               0.0                               0.0
# 29                               0.0                              40.0
# 30                              11.0                              20.0
# 31                               0.0                               0.0
# 32                               0.0                               0.0
# 33                               4.0                              30.0
# 34                               0.0                              50.0
# 35                               0.0                               0.0
# 36                               1.0                              35.0
# 37                               1.0                              25.0
# 38                               7.0                              25.0
# 39                               6.0                              40.0
#
#     Current Price (2022Jul) (Storage)  ...  \
# 0                           30.000000  ...
# 1                           23.448276  ...
# 2                           50.000000  ...
# 3                           25.157895  ...
# 4                           25.000000  ...
# 5                           30.000000  ...
# 6                            0.000000  ...
# 7                            0.000000  ...
# 8                           45.238095  ...
# 9                            0.000000  ...
# 10                           0.000000  ...
# 11                          35.000000  ...
# 12                          34.787234  ...
# 13                          27.564103  ...
# 14                          16.904762  ...
# 15                           0.000000  ...
# 16                           0.000000  ...
# 17                          23.621739  ...
# 18                          35.677407  ...
# 19                           0.000000  ...
# 20                           0.000000  ...
# 21                           0.000000  ...
# 22                          12.745000  ...
# 23                           0.000000  ...
# 24                          24.823462  ...
# 25                          19.372326  ...
# 26                           0.000000  ...
# 27                           0.000000  ...
# 28                           0.000000  ...
# 29                          38.690000  ...
# 30                          19.880952  ...
# 31                           0.000000  ...
# 32                           0.000000  ...
# 33                          30.000000  ...
# 34                          39.090909  ...
# 35                           0.000000  ...
# 36                          28.333333  ...
# 37                          17.539545  ...
# 38                          31.443784  ...
# 39                          14.680700  ...
#
#     Ending_Lease_Rate% (2023Apr) (Storage)  Total Units (2023May) (Storage)  \
# 0                                    63.83                             47.0
# 1                                    39.68                             63.0
# 2                                    71.43                             70.0
# 3                                     6.36                            393.0
# 4                                     9.88                            253.0
# 5                                    13.95                            215.0
# 6                                     0.00                              0.0
# 7                                     0.00                              0.0
# 8                                    83.33                             60.0
# 9                                     0.00                              0.0
# 10                                    0.00                              0.0
# 11                                   71.43                             49.0
# 12                                   72.92                             48.0
# 13                                   13.09                            191.0
# 14                                   11.83                            169.0
# 15                                    0.00                              0.0
# 16                                    0.00                              0.0
# 17                                   20.75                            241.0
# 18                                   15.04                            266.0
# 19                                    0.00                              0.0
# 20                                    0.00                              0.0
# 21                                    0.00                              0.0
# 22                                   86.21                             29.0
# 23                                    0.00                              0.0
# 24                                   62.50                             48.0
# 25                                   11.11                            225.0
# 26                                    0.00                              0.0
# 27                                    0.00                              0.0
# 28                                    0.00                              0.0
# 29                                  153.85                             26.0
# 30                                    9.66                            207.0
# 31                                    0.00                              0.0
# 32                                    0.00                              0.0
# 33                                   23.26                            130.0
# 34                                  166.67                             30.0
# 35                                    0.00                              0.0
# 36                                   11.95                            293.0
# 37                                   22.73                            110.0
# 38                                   39.06                             64.0
# 39                                   19.32                            199.0
#
#     Occupied (2023May) (Storage)  Percentage% (2023May) (Storage)  \
# 0                           27.0                            57.45
# 1                           47.0                            74.60
# 2                           52.0                            74.29
# 3                          206.0                            52.42
# 4                          140.0                            55.34
# 5                           90.0                            41.86
# 6                            0.0                             0.00
# 7                            0.0                             0.00
# 8                           24.0                            40.00
# 9                            0.0                             0.00
# 10                           0.0                             0.00
# 11                          20.0                            40.82
# 12                          48.0                           100.00
# 13                          54.0                            28.27
# 14                          45.0                            26.63
# 15                           0.0                             0.00
# 16                           0.0                             0.00
# 17                         103.0                            42.74
# 18                         117.0                            43.98
# 19                           0.0                             0.00
# 20                           0.0                             0.00
# 21                           0.0                             0.00
# 22                          23.0                            79.31
# 23                           0.0                             0.00
# 24                          39.0                            81.25
# 25                         176.0                            78.22
# 26                           0.0                             0.00
# 27                           0.0                             0.00
# 28                           0.0                             0.00
# 29                          16.0                            61.54
# 30                         118.0                            57.00
# 31                           0.0                             0.00
# 32                           0.0                             0.00
# 33                          60.0                            46.15
# 34                          30.0                           100.00
# 35                           0.0                             0.00
# 36                          10.0                             3.41
# 37                          73.0                            66.36
# 38                          36.0                            56.25
# 39                         134.0                            67.34
#
#     New Lease (2023May) (Storage)  Ending Lease (2023May) (Storage)  \
# 0                             0.0                              27.0
# 1                             0.0                              18.0
# 2                             0.0                              25.0
# 3                             3.0                             194.0
# 4                             1.0                             121.0
# 5                             3.0                             130.0
# 6                             0.0                               0.0
# 7                             0.0                               0.0
# 8                             2.0                              47.0
# 9                             0.0                               0.0
# 10                            0.0                               0.0
# 11                            0.0                              41.0
# 12                            3.0                              16.0
# 13                            0.0                             148.0
# 14                            2.0                             133.0
# 15                            0.0                               0.0
# 16                            0.0                               0.0
# 17                            4.0                             156.0
# 18                            5.0                             158.0
# 19                            0.0                               0.0
# 20                            0.0                               0.0
# 21                            0.0                               0.0
# 22                            1.0                              16.0
# 23                            0.0                               0.0
# 24                            3.0                              12.0
# 25                           23.0                              76.0
# 26                            0.0                               0.0
# 27                            0.0                               0.0
# 28                            0.0                               0.0
# 29                            0.0                              10.0
# 30                            4.0                              98.0
# 31                            0.0                               0.0
# 32                            0.0                               0.0
# 33                            1.0                              75.0
# 34                            1.0                               1.0
# 35                            0.0                               0.0
# 36                            0.0                             284.0
# 37                            1.0                              45.0
# 38                            3.0                              33.0
# 39                            0.0                             106.0
#
#     Market Price (2023May) (Storage)  Current Price (2023May) (Storage)  \
# 0                               30.0                          30.000000
# 1                               25.0                          23.500000
# 2                               50.0                          50.000000
# 3                               25.0                          25.144231
# 4                               25.0                          25.000000
# 5                               30.0                          30.000000
# 6                                0.0                           0.000000
# 7                                0.0                           0.000000
# 8                               50.0                          45.312500
# 9                                0.0                           0.000000
# 10                               0.0                           0.000000
# 11                              35.0                          35.000000
# 12                              35.0                          35.000000
# 13                              25.0                          60.196078
# 14                              20.0                          16.818182
# 15                               0.0                           0.000000
# 16                               0.0                           0.000000
# 17                              50.0                          25.965125
# 18                              40.0                          36.729035
# 19                               0.0                           0.000000
# 20                               0.0                           0.000000
# 21                               0.0                           0.000000
# 22                              25.0                          14.940000
# 23                               0.0                           0.000000
# 24                              30.0                          27.172571
# 25                              25.0                          20.130076
# 26                               0.0                           0.000000
# 27                               0.0                           0.000000
# 28                               0.0                           0.000000
# 29                              40.0                          39.668750
# 30                              20.0                          19.895833
# 31                               0.0                           0.000000
# 32                               0.0                           0.000000
# 33                              30.0                          30.000000
# 34                              50.0                          40.869565
# 35                               0.0                           0.000000
# 36                              35.0                          25.000000
# 37                              25.0                          17.847258
# 38                              25.0                          34.959412
# 39                              40.0                          18.940781
#
#     Lease_Turnover_Rate% (2023May) (Storage)  \
# 0                                      57.45
# 1                                      28.57
# 2                                      35.71
# 3                                      49.36
# 4                                      47.83
# 5                                      60.47
# 6                                       0.00
# 7                                       0.00
# 8                                      78.33
# 9                                       0.00
# 10                                      0.00
# 11                                     83.67
# 12                                     33.33
# 13                                     77.49
# 14                                     78.70
# 15                                      0.00
# 16                                      0.00
# 17                                     64.73
# 18                                     59.40
# 19                                      0.00
# 20                                      0.00
# 21                                      0.00
# 22                                     55.17
# 23                                      0.00
# 24                                     25.00
# 25                                     33.78
# 26                                      0.00
# 27                                      0.00
# 28                                      0.00
# 29                                     38.46
# 30                                     47.34
# 31                                      0.00
# 32                                      0.00
# 33                                     57.69
# 34                                      3.33
# 35                                      0.00
# 36                                     96.93
# 37                                     40.91
# 38                                     51.56
# 39                                     53.27
#
#     Ending_Lease_Rate% (2023May) (Storage)
# 0                                    63.83
# 1                                    39.68
# 2                                    71.43
# 3                                     6.36
# 4                                     9.88
# 5                                    13.95
# 6                                     0.00
# 7                                     0.00
# 8                                    83.33
# 9                                     0.00
# 10                                    0.00
# 11                                   71.43
# 12                                   72.92
# 13                                   13.09
# 14                                   11.83
# 15                                    0.00
# 16                                    0.00
# 17                                   20.75
# 18                                   15.04
# 19                                    0.00
# 20                                    0.00
# 21                                    0.00
# 22                                   86.21
# 23                                    0.00
# 24                                   62.50
# 25                                   11.11
# 26                                    0.00
# 27                                    0.00
# 28                                    0.00
# 29                                  153.85
# 30                                    9.66
# 31                                    0.00
# 32                                    0.00
# 33                                   23.08
# 34                                  166.67
# 35                                    0.00
# 36                                   11.95
# 37                                   22.73
# 38                                   39.06
# 39                                   20.10
#
# [40 rows x 66 columns]

# %%
# Summary Statistics
summary_stats = df_storage.describe()
summary_stats
# Out:
#        2022 Storage Comp price  2023 Storage Comp price  \
# count                40.000000                40.000000
# mean                 18.291667                14.247917
# std                  20.917309                19.175643
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   7.500000                 0.000000
# 75%                  35.000000                27.500000
# max                  60.000000                63.750000
#
#        Total Units (2022Jul) (Storage)  Occupied (2022Jul) (Storage)  \
# count                        40.000000                     40.000000
# mean                         85.750000                     42.925000
# std                         106.371326                     57.706324
# min                           0.000000                      0.000000
# 25%                           0.000000                      0.000000
# 50%                          47.500000                     26.500000
# 75%                         174.500000                     51.250000
# max                         393.000000                    214.000000
#
#        Percentage% (2022Jul) (Storage)  New Lease (2022Jul) (Storage)  \
# count                        40.000000                      40.000000
# mean                         35.485250                       1.875000
# std                          35.459393                       3.817554
# min                           0.000000                       0.000000
# 25%                           0.000000                       0.000000
# 50%                          33.580000                       0.000000
# 75%                          62.942500                       2.250000
# max                         100.000000                      21.000000
#
#        Ending Lease (2022Jul) (Storage)  Market Price (2022Jul) (Storage)  \
# count                         40.000000                          40.00000
# mean                           3.475000                          18.87500
# std                            7.260669                          17.19002
# min                            0.000000                           0.00000
# 25%                            0.000000                           0.00000
# 50%                            0.500000                          25.00000
# 75%                            4.500000                          30.00000
# max                           42.000000                          50.00000
#
#        Current Price (2022Jul) (Storage)  \
# count                          40.000000
# mean                           16.974988
# std                            15.794048
# min                             0.000000
# 25%                             0.000000
# 50%                            18.455936
# 75%                            30.000000
# max                            50.000000
#
#        Lease_Turnover_Rate% (2022Jul) (Storage)  ...  \
# count                                 40.000000  ...
# mean                                   2.669000  ...
# std                                    4.475682  ...
# min                                    0.000000  ...
# 25%                                    0.000000  ...
# 50%                                    0.170000  ...
# 75%                                    3.870000  ...
# max                                   18.670000  ...
#
#        Ending_Lease_Rate% (2023Apr) (Storage)  \
# count                               40.000000
# mean                                27.496000
# std                                 40.911821
# min                                  0.000000
# 25%                                  0.000000
# 50%                                 11.470000
# 75%                                 39.215000
# max                                166.670000
#
#        Total Units (2023May) (Storage)  Occupied (2023May) (Storage)  \
# count                        40.000000                     40.000000
# mean                         85.650000                     42.200000
# std                         106.367662                     53.935004
# min                           0.000000                      0.000000
# 25%                           0.000000                      0.000000
# 50%                          47.500000                     23.500000
# 75%                         174.500000                     55.500000
# max                         393.000000                    206.000000
#
#        Percentage% (2023May) (Storage)  New Lease (2023May) (Storage)  \
# count                        40.000000                      40.000000
# mean                         34.380750                       1.500000
# std                          33.394091                       3.768969
# min                           0.000000                       0.000000
# 25%                           0.000000                       0.000000
# 50%                          40.410000                       0.000000
# 75%                          58.472500                       2.000000
# max                         100.000000                      23.000000
#
#        Ending Lease (2023May) (Storage)  Market Price (2023May) (Storage)  \
# count                         40.000000                         40.000000
# mean                          49.250000                         19.625000
# std                           68.572159                         17.880927
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                           16.000000                         25.000000
# 75%                           81.500000                         31.250000
# max                          284.000000                         50.000000
#
#        Current Price (2023May) (Storage)  \
# count                          40.000000
# mean                           18.202235
# std                            17.335650
# min                             0.000000
# 25%                             0.000000
# 50%                            19.418307
# 75%                            30.000000
# max                            60.196078
#
#        Lease_Turnover_Rate% (2023May) (Storage)  \
# count                                 40.000000
# mean                                  31.462000
# std                                   30.708193
# min                                    0.000000
# 25%                                    0.000000
# 50%                                   33.555000
# 75%                                   55.740000
# max                                   96.930000
#
#        Ending_Lease_Rate% (2023May) (Storage)
# count                               40.000000
# mean                                27.511000
# std                                 40.908499
# min                                  0.000000
# 25%                                  0.000000
# 50%                                 11.470000
# 75%                                 39.215000
# max                                166.670000
#
# [8 rows x 65 columns]

# %%
# Correlation Matrix
correlation_matrix = df_storage.corr()
correlation_matrix
# Out:
# <ipython-input-7-bb1db7af98ec>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_storage.corr()
#                                           2022 Storage Comp price  \
# 2022 Storage Comp price                                  1.000000
# 2023 Storage Comp price                                  0.112559
# Total Units (2022Jul) (Storage)                          0.142087
# Occupied (2022Jul) (Storage)                             0.329717
# Percentage% (2022Jul) (Storage)                          0.648535
# ...                                                           ...
# Ending Lease (2023May) (Storage)                         0.076206
# Market Price (2023May) (Storage)                         0.640661
# Current Price (2023May) (Storage)                        0.506806
# Lease_Turnover_Rate% (2023May) (Storage)                 0.387342
# Ending_Lease_Rate% (2023May) (Storage)                   0.576826
#
#                                           2023 Storage Comp price  \
# 2022 Storage Comp price                                  0.112559
# 2023 Storage Comp price                                  1.000000
# Total Units (2022Jul) (Storage)                          0.280360
# Occupied (2022Jul) (Storage)                             0.237867
# Percentage% (2022Jul) (Storage)                          0.369054
# ...                                                           ...
# Ending Lease (2023May) (Storage)                         0.198127
# Market Price (2023May) (Storage)                         0.469159
# Current Price (2023May) (Storage)                        0.462559
# Lease_Turnover_Rate% (2023May) (Storage)                 0.210060
# Ending_Lease_Rate% (2023May) (Storage)                   0.254428
#
#                                           Total Units (2022Jul) (Storage)  \
# 2022 Storage Comp price                                          0.142087
# 2023 Storage Comp price                                          0.280360
# Total Units (2022Jul) (Storage)                                  1.000000
# Occupied (2022Jul) (Storage)                                     0.807454
# Percentage% (2022Jul) (Storage)                                  0.339793
# ...                                                                   ...
# Ending Lease (2023May) (Storage)                                 0.934247
# Market Price (2023May) (Storage)                                 0.540806
# Current Price (2023May) (Storage)                                0.484156
# Lease_Turnover_Rate% (2023May) (Storage)                         0.700467
# Ending_Lease_Rate% (2023May) (Storage)                          -0.092712
#
#                                           Occupied (2022Jul) (Storage)  \
# 2022 Storage Comp price                                       0.329717
# 2023 Storage Comp price                                       0.237867
# Total Units (2022Jul) (Storage)                               0.807454
# Occupied (2022Jul) (Storage)                                  1.000000
# Percentage% (2022Jul) (Storage)                               0.600384
# ...                                                                ...
# Ending Lease (2023May) (Storage)                              0.575797
# Market Price (2023May) (Storage)                              0.507155
# Current Price (2023May) (Storage)                             0.386292
# Lease_Turnover_Rate% (2023May) (Storage)                      0.454111
# Ending_Lease_Rate% (2023May) (Storage)                        0.006364
#
#                                           Percentage% (2022Jul) (Storage)  \
# 2022 Storage Comp price                                          0.648535
# 2023 Storage Comp price                                          0.369054
# Total Units (2022Jul) (Storage)                                  0.339793
# Occupied (2022Jul) (Storage)                                     0.600384
# Percentage% (2022Jul) (Storage)                                  1.000000
# ...                                                                   ...
# Ending Lease (2023May) (Storage)                                 0.157941
# Market Price (2023May) (Storage)                                 0.798296
# Current Price (2023May) (Storage)                                0.693093
# Lease_Turnover_Rate% (2023May) (Storage)                         0.464343
# Ending_Lease_Rate% (2023May) (Storage)                           0.713503
#
#                                           New Lease (2022Jul) (Storage)  \
# 2022 Storage Comp price                                        0.305249
# 2023 Storage Comp price                                        0.164943
# Total Units (2022Jul) (Storage)                                0.451141
# Occupied (2022Jul) (Storage)                                   0.538739
# Percentage% (2022Jul) (Storage)                                0.364186
# ...                                                                 ...
# Ending Lease (2023May) (Storage)                               0.334718
# Market Price (2023May) (Storage)                               0.397463
# Current Price (2023May) (Storage)                              0.295132
# Lease_Turnover_Rate% (2023May) (Storage)                       0.335894
# Ending_Lease_Rate% (2023May) (Storage)                         0.029216
#
#                                           Ending Lease (2022Jul) (Storage)  \
# 2022 Storage Comp price                                           0.200480
# 2023 Storage Comp price                                           0.115218
# Total Units (2022Jul) (Storage)                                   0.450844
# Occupied (2022Jul) (Storage)                                      0.557537
# Percentage% (2022Jul) (Storage)                                   0.346875
# ...                                                                    ...
# Ending Lease (2023May) (Storage)                                  0.318955
# Market Price (2023May) (Storage)                                  0.297658
# Current Price (2023May) (Storage)                                 0.294929
# Lease_Turnover_Rate% (2023May) (Storage)                          0.324620
# Ending_Lease_Rate% (2023May) (Storage)                           -0.033736
#
#                                           Market Price (2022Jul) (Storage)  \
# 2022 Storage Comp price                                           0.640472
# 2023 Storage Comp price                                           0.392138
# Total Units (2022Jul) (Storage)                                   0.498352
# Occupied (2022Jul) (Storage)                                      0.478498
# Percentage% (2022Jul) (Storage)                                   0.818475
# ...                                                                    ...
# Ending Lease (2023May) (Storage)                                  0.458898
# Market Price (2023May) (Storage)                                  0.974604
# Current Price (2023May) (Storage)                                 0.907401
# Lease_Turnover_Rate% (2023May) (Storage)                          0.740883
# Ending_Lease_Rate% (2023May) (Storage)                            0.722962
#
#                                           Current Price (2022Jul) (Storage)  \
# 2022 Storage Comp price                                            0.556673
# 2023 Storage Comp price                                            0.449902
# Total Units (2022Jul) (Storage)                                    0.478334
# Occupied (2022Jul) (Storage)                                       0.399269
# Percentage% (2022Jul) (Storage)                                    0.742919
# ...                                                                     ...
# Ending Lease (2023May) (Storage)                                   0.441372
# Market Price (2023May) (Storage)                                   0.935667
# Current Price (2023May) (Storage)                                  0.954331
# Lease_Turnover_Rate% (2023May) (Storage)                           0.737461
# Ending_Lease_Rate% (2023May) (Storage)                             0.691891
#
#                                           Lease_Turnover_Rate% (2022Jul) (Storage)  \
# 2022 Storage Comp price                                                   0.397546
# 2023 Storage Comp price                                                   0.149438
# Total Units (2022Jul) (Storage)                                           0.255673
# Occupied (2022Jul) (Storage)                                              0.380584
# Percentage% (2022Jul) (Storage)                                           0.502023
# ...                                                                            ...
# Ending Lease (2023May) (Storage)                                          0.162581
# Market Price (2023May) (Storage)                                          0.428604
# Current Price (2023May) (Storage)                                         0.465657
# Lease_Turnover_Rate% (2023May) (Storage)                                  0.412977
# Ending_Lease_Rate% (2023May) (Storage)                                    0.207022
#
#                                           ...  \
# 2022 Storage Comp price                   ...
# 2023 Storage Comp price                   ...
# Total Units (2022Jul) (Storage)           ...
# Occupied (2022Jul) (Storage)              ...
# Percentage% (2022Jul) (Storage)           ...
# ...                                       ...
# Ending Lease (2023May) (Storage)          ...
# Market Price (2023May) (Storage)          ...
# Current Price (2023May) (Storage)         ...
# Lease_Turnover_Rate% (2023May) (Storage)  ...
# Ending_Lease_Rate% (2023May) (Storage)    ...
#
#                                           Ending_Lease_Rate% (2023Apr) (Storage)  \
# 2022 Storage Comp price                                                 0.575949
# 2023 Storage Comp price                                                 0.254942
# Total Units (2022Jul) (Storage)                                        -0.093248
# Occupied (2022Jul) (Storage)                                            0.004959
# Percentage% (2022Jul) (Storage)                                         0.712605
# ...                                                                          ...
# Ending Lease (2023May) (Storage)                                       -0.122852
# Market Price (2023May) (Storage)                                        0.685680
# Current Price (2023May) (Storage)                                       0.635628
# Lease_Turnover_Rate% (2023May) (Storage)                                0.277386
# Ending_Lease_Rate% (2023May) (Storage)                                  0.999995
#
#                                           Total Units (2023May) (Storage)  \
# 2022 Storage Comp price                                          0.139132
# 2023 Storage Comp price                                          0.281631
# Total Units (2022Jul) (Storage)                                  0.999631
# Occupied (2022Jul) (Storage)                                     0.799577
# Percentage% (2022Jul) (Storage)                                  0.333788
# ...                                                                   ...
# Ending Lease (2023May) (Storage)                                 0.935200
# Market Price (2023May) (Storage)                                 0.539591
# Current Price (2023May) (Storage)                                0.486759
# Lease_Turnover_Rate% (2023May) (Storage)                         0.700323
# Ending_Lease_Rate% (2023May) (Storage)                          -0.092822
#
#                                           Occupied (2023May) (Storage)  \
# 2022 Storage Comp price                                       0.250507
# 2023 Storage Comp price                                       0.329350
# Total Units (2022Jul) (Storage)                               0.866290
# Occupied (2022Jul) (Storage)                                  0.964174
# Percentage% (2022Jul) (Storage)                               0.551563
# ...                                                                ...
# Ending Lease (2023May) (Storage)                              0.634883
# Market Price (2023May) (Storage)                              0.514412
# Current Price (2023May) (Storage)                             0.436574
# Lease_Turnover_Rate% (2023May) (Storage)                      0.485308
# Ending_Lease_Rate% (2023May) (Storage)                       -0.010247
#
#                                           Percentage% (2023May) (Storage)  \
# 2022 Storage Comp price                                          0.585868
# 2023 Storage Comp price                                          0.471056
# Total Units (2022Jul) (Storage)                                  0.371005
# Occupied (2022Jul) (Storage)                                     0.569595
# Percentage% (2022Jul) (Storage)                                  0.975539
# ...                                                                   ...
# Ending Lease (2023May) (Storage)                                 0.187271
# Market Price (2023May) (Storage)                                 0.797344
# Current Price (2023May) (Storage)                                0.720083
# Lease_Turnover_Rate% (2023May) (Storage)                         0.469385
# Ending_Lease_Rate% (2023May) (Storage)                           0.693967
#
#                                           New Lease (2023May) (Storage)  \
# 2022 Storage Comp price                                        0.139041
# 2023 Storage Comp price                                        0.133591
# Total Units (2022Jul) (Storage)                                0.410284
# Occupied (2022Jul) (Storage)                                   0.526099
# Percentage% (2022Jul) (Storage)                                0.321825
# ...                                                                 ...
# Ending Lease (2023May) (Storage)                               0.235331
# Market Price (2023May) (Storage)                               0.231137
# Current Price (2023May) (Storage)                              0.175693
# Lease_Turnover_Rate% (2023May) (Storage)                       0.180037
# Ending_Lease_Rate% (2023May) (Storage)                        -0.019130
#
#                                           Ending Lease (2023May) (Storage)  \
# 2022 Storage Comp price                                           0.076206
# 2023 Storage Comp price                                           0.198127
# Total Units (2022Jul) (Storage)                                   0.934247
# Occupied (2022Jul) (Storage)                                      0.575797
# Percentage% (2022Jul) (Storage)                                   0.157941
# ...                                                                    ...
# Ending Lease (2023May) (Storage)                                  1.000000
# Market Price (2023May) (Storage)                                  0.499773
# Current Price (2023May) (Storage)                                 0.460489
# Lease_Turnover_Rate% (2023May) (Storage)                          0.768204
# Ending_Lease_Rate% (2023May) (Storage)                           -0.122500
#
#                                           Market Price (2023May) (Storage)  \
# 2022 Storage Comp price                                           0.640661
# 2023 Storage Comp price                                           0.469159
# Total Units (2022Jul) (Storage)                                   0.540806
# Occupied (2022Jul) (Storage)                                      0.507155
# Percentage% (2022Jul) (Storage)                                   0.798296
# ...                                                                    ...
# Ending Lease (2023May) (Storage)                                  0.499773
# Market Price (2023May) (Storage)                                  1.000000
# Current Price (2023May) (Storage)                                 0.889190
# Lease_Turnover_Rate% (2023May) (Storage)                          0.751635
# Ending_Lease_Rate% (2023May) (Storage)                            0.686228
#
#                                           Current Price (2023May) (Storage)  \
# 2022 Storage Comp price                                            0.506806
# 2023 Storage Comp price                                            0.462559
# Total Units (2022Jul) (Storage)                                    0.484156
# Occupied (2022Jul) (Storage)                                       0.386292
# Percentage% (2022Jul) (Storage)                                    0.693093
# ...                                                                     ...
# Ending Lease (2023May) (Storage)                                   0.460489
# Market Price (2023May) (Storage)                                   0.889190
# Current Price (2023May) (Storage)                                  1.000000
# Lease_Turnover_Rate% (2023May) (Storage)                           0.746665
# Ending_Lease_Rate% (2023May) (Storage)                             0.635624
#
#                                           Lease_Turnover_Rate% (2023May) (Storage)  \
# 2022 Storage Comp price                                                   0.387342
# 2023 Storage Comp price                                                   0.210060
# Total Units (2022Jul) (Storage)                                           0.700467
# Occupied (2022Jul) (Storage)                                              0.454111
# Percentage% (2022Jul) (Storage)                                           0.464343
# ...                                                                            ...
# Ending Lease (2023May) (Storage)                                          0.768204
# Market Price (2023May) (Storage)                                          0.751635
# Current Price (2023May) (Storage)                                         0.746665
# Lease_Turnover_Rate% (2023May) (Storage)                                  1.000000
# Ending_Lease_Rate% (2023May) (Storage)                                    0.277659
#
#                                           Ending_Lease_Rate% (2023May) (Storage)
# 2022 Storage Comp price                                                 0.576826
# 2023 Storage Comp price                                                 0.254428
# Total Units (2022Jul) (Storage)                                        -0.092712
# Occupied (2022Jul) (Storage)                                            0.006364
# Percentage% (2022Jul) (Storage)                                         0.713503
# ...                                                                          ...
# Ending Lease (2023May) (Storage)                                       -0.122500
# Market Price (2023May) (Storage)                                        0.686228
# Current Price (2023May) (Storage)                                       0.635624
# Lease_Turnover_Rate% (2023May) (Storage)                                0.277659
# Ending_Lease_Rate% (2023May) (Storage)                                  1.000000
#
# [65 rows x 65 columns]

# %%
# Histogram for Outdoor Parking Percentage in May 2023
plt.hist(df_storage['Percentage% (2023May) (Storage)'], bins=10, edgecolor='black')
plt.title('Distribution of Occupancy Percentage (Storage) - May 2023')
plt.xlabel('Occupancy Percentage')
plt.ylabel('Frequency')
plt.show()

# %%
# Select features and target for the storage dataset
feature_columns_storage = [col for col in df_storage.columns if col not in ['Property Code', 'Percentage% (2023May) (Storage)']]
target_column_storage = 'Percentage% (2023May) (Storage)'

# %%
# Prepare the data
X_storage = df_storage[feature_columns_storage]
y_storage = df_storage[target_column_storage]

# %%
# Split the data into training and testing sets
X_train_storage, X_test_storage, y_train_storage, y_test_storage = train_test_split(X_storage, y_storage, test_size=0.2, random_state=42)

# %%
# Initialize and train the Random Forest model
rf_storage = RandomForestRegressor(random_state=42)
rf_storage.fit(X_train_storage, y_train_storage)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Get feature importances
importances_storage = rf_storage.feature_importances_
features_importances_storage = sorted(zip(importances_storage, X_storage.columns), reverse=True)

# %%
# Print feature importances
for importance, name in features_importances_storage:
    print(f"Feature: {name}, Importance: {importance}")
# Out:
# Feature: Percentage% (2023Apr) (Storage), Importance: 0.49484372911822233
# Feature: Percentage% (2022Aug) (Storage), Importance: 0.09359491515412487
# Feature: Percentage% (2022Dec) (Storage), Importance: 0.08878912806174506
# Feature: Percentage% (2022Oct) (Storage), Importance: 0.08003326326903248
# Feature: Percentage% (2022Sep) (Storage), Importance: 0.06094604143291434
# Feature: Percentage% (2022Jul) (Storage), Importance: 0.04462056981478458
# Feature: Occupied (2023May) (Storage), Importance: 0.019917196044817585
# Feature: Lease_Turnover_Rate% (2022Dec) (Storage), Importance: 0.013026823944148004
# Feature: Occupied (2022Aug) (Storage), Importance: 0.010128474340055382
# Feature: Current Price (2023Apr) (Storage), Importance: 0.009492309821666493
# Feature: Occupied (2022Dec) (Storage), Importance: 0.009177100880523544
# Feature: Lease_Turnover_Rate% (2023Apr) (Storage), Importance: 0.008747455052421896
# Feature: Market Price (2022Dec) (Storage), Importance: 0.008480140996493017
# Feature: Lease_Turnover_Rate% (2022Sep) (Storage), Importance: 0.005578282243276829
# Feature: Lease_Turnover_Rate% (2023May) (Storage), Importance: 0.005128266634028377
# Feature: Lease_Turnover_Rate% (2022Aug) (Storage), Importance: 0.0046795782506912735
# Feature: Total Units (2022Sep) (Storage), Importance: 0.0026942414726620007
# Feature: Occupied (2022Sep) (Storage), Importance: 0.0026713051962916658
# Feature: New Lease (2022Oct) (Storage), Importance: 0.002669137392092626
# Feature: Ending Lease (2023Apr) (Storage), Importance: 0.002650533723680013
# Feature: Occupied (2022Oct) (Storage), Importance: 0.0025682134465972602
# Feature: Ending Lease (2022Sep) (Storage), Importance: 0.0019676599132668754
# Feature: Ending Lease (2022Aug) (Storage), Importance: 0.0018598939904713287
# Feature: Lease_Turnover_Rate% (2022Jul) (Storage), Importance: 0.0018341562630848926
# Feature: Occupied (2023Apr) (Storage), Importance: 0.0017070682114640665
# Feature: Ending_Lease_Rate% (2022Jul) (Storage), Importance: 0.0016600561215215637
# Feature: Total Units (2023Apr) (Storage), Importance: 0.0015973501837789376
# Feature: Ending_Lease_Rate% (2023May) (Storage), Importance: 0.0015807973119779956
# Feature: Ending Lease (2022Jul) (Storage), Importance: 0.0012062595852134802
# Feature: Ending Lease (2023May) (Storage), Importance: 0.0012035812926719798
# Feature: Ending_Lease_Rate% (2023Apr) (Storage), Importance: 0.00117064378512918
# Feature: Current Price (2023May) (Storage), Importance: 0.0011654341910171423
# Feature: Market Price (2022Jul) (Storage), Importance: 0.0010838318410830844
# Feature: New Lease (2022Dec) (Storage), Importance: 0.001045044953435188
# Feature: Ending_Lease_Rate% (2022Dec) (Storage), Importance: 0.0009873162759751542
# Feature: New Lease (2022Jul) (Storage), Importance: 0.0008277701064921942
# Feature: Market Price (2022Oct) (Storage), Importance: 0.0007849203637137001
# Feature: Current Price (2022Aug) (Storage), Importance: 0.0007297661603743495
# Feature: New Lease (2023Apr) (Storage), Importance: 0.0006987321112864827
# Feature: Ending_Lease_Rate% (2022Oct) (Storage), Importance: 0.0006916471910152004
# Feature: Lease_Turnover_Rate% (2022Oct) (Storage), Importance: 0.0005321858630176197
# Feature: Current Price (2022Oct) (Storage), Importance: 0.00045136097541772965
# Feature: Ending_Lease_Rate% (2022Sep) (Storage), Importance: 0.0004258935709081483
# Feature: Total Units (2022Oct) (Storage), Importance: 0.00042385194006600317
# Feature: Current Price (2022Dec) (Storage), Importance: 0.00041169651160249824
# Feature: 2022 Storage Comp price, Importance: 0.00039298915554979565
# Feature: Market Price (2023Apr) (Storage), Importance: 0.000385098216640745
# Feature: Ending_Lease_Rate% (2022Aug) (Storage), Importance: 0.0003356327588410837
# Feature: Ending Lease (2022Dec) (Storage), Importance: 0.0002697083667272396
# Feature: Total Units (2023May) (Storage), Importance: 0.0002490576504961898
# Feature: Total Units (2022Aug) (Storage), Importance: 0.0002284212679748502
# Feature: Market Price (2022Aug) (Storage), Importance: 0.00022684967627868715
# Feature: Ending Lease (2022Oct) (Storage), Importance: 0.0002239558445292385
# Feature: Market Price (2022Sep) (Storage), Importance: 0.0002046317461539924
# Feature: 2023 Storage Comp price, Importance: 0.00017896299874335542
# Feature: Total Units (2022Jul) (Storage), Importance: 0.0001595541281366869
# Feature: Market Price (2023May) (Storage), Importance: 0.0001480769732164362
# Feature: New Lease (2023May) (Storage), Importance: 0.0001124415595433498
# Feature: Occupied (2022Jul) (Storage), Importance: 0.00010357557756168336
# Feature: New Lease (2022Sep) (Storage), Importance: 0.00010110150123385144
# Feature: New Lease (2022Aug) (Storage), Importance: 8.862546373424427e-05
# Feature: Total Units (2022Dec) (Storage), Importance: 5.297149367617252e-05
# Feature: Current Price (2022Sep) (Storage), Importance: 4.4137255557962285e-05
# Feature: Current Price (2022Jul) (Storage), Importance: 1.0583361150156313e-05

# %%
# Select the most important features
important_features_storage = [name for importance, name in features_importances_storage if importance > 0.01]

# %%
# Prepare the data with only the most important features
X_storage = df_storage[important_features_storage]

# Split the data into training and testing sets again
X_train_storage, X_test_storage, y_train_storage, y_test_storage = train_test_split(X_storage, y_storage, test_size=0.2, random_state=42)

# %%
# Initialize and train the Random Forest model again
rf_storage = RandomForestRegressor(random_state=42)
rf_storage.fit(X_train_storage, y_train_storage)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict the target variable for the test data
y_pred_storage = rf_storage.predict(X_test_storage)

# %%
# Calculate and print the Root Mean Squared Error (RMSE)
rmse_storage = np.sqrt(mean_squared_error(y_test_storage, y_pred_storage))
print('RMSE for Storage:', rmse_storage)
# Out:
# RMSE for Storage: 3.6470538935557295

# %%
# Scatter plot of actual vs. predicted values
plt.scatter(y_test_storage, y_pred_storage, color='blue')
plt.plot([y_test_storage.min(), y_test_storage.max()], [y_test_storage.min(), y_test_storage.max()], 'k--', lw=4, color='red')
plt.xlabel('Actual Occupancy Percentage')
plt.ylabel('Predicted Occupancy Percentage')
plt.title('Actual vs. Predicted Occupancy Percentage (Storage) - May 2023')
plt.show()
# Out:
# <ipython-input-20-f662e9b3558e>:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([y_test_storage.min(), y_test_storage.max()], [y_test_storage.min(), y_test_storage.max()], 'k--', lw=4, color='red')

# %%
# Residual plot
residuals_storage = y_test_storage - y_pred_storage
plt.scatter(y_pred_storage, residuals_storage, color='green')
plt.hlines(y=0, xmin=y_pred_storage.min(), xmax=y_pred_storage.max(), colors='red', linestyles='dashed')
plt.xlabel('Predicted Occupancy Percentage')
plt.ylabel('Residuals')
plt.title('Residual Plot (Storage) - May 2023')
plt.show()

# %% [markdown]
# # **Optimization**

# %%
# Create a new concrete model for storage optimization
model_storage = ConcreteModel()

# Define the decision variables
model_storage.price = Var(df_storage.index, domain=NonNegativeReals)

# %%
# Define the objective function
def objective_rule_storage(model):
    return sum(y_storage[i] * model_storage.price[i] for i in df_storage.index)
model_storage.objective = Objective(rule=objective_rule_storage, sense=maximize)

# %%
# Define the lower limit constraint for each property's price (must be >= market price)
def price_lower_limit_constraint_rule_storage(model, i):
    return model_storage.price[i] >= df_storage.loc[i, 'Market Price (2023May) (Storage)']
model_storage.price_lower_limit_constraint = Constraint(df_storage.index, rule=price_lower_limit_constraint_rule_storage)

# Define the upper limit constraint for each property's price (must be <= 1.1 times market price)
price_upper_limit_storage = 1.1
def price_upper_limit_constraint_rule_storage(model, i):
    return model_storage.price[i] <= price_upper_limit_storage * df_storage.loc[i, 'Market Price (2023May) (Storage)']
model_storage.price_upper_limit_constraint = Constraint(df_storage.index, rule=price_upper_limit_constraint_rule_storage)

# %%
# Solve the model
solver = SolverFactory('glpk')
solver.solve(model_storage)
# Out:
# {'Problem': [{'Name': 'unknown', 'Lower bound': 50112.81, 'Upper bound': 50112.81, 'Number of objectives': 1, 'Number of constraints': 80, 'Number of variables': 40, 'Number of nonzeros': 80, 'Sense': 'maximize'}], 'Solver': [{'Status': 'ok', 'Termination condition': 'optimal', 'Statistics': {'Branch and bound': {'Number of bounded subproblems': 0, 'Number of created subproblems': 0}}, 'Error rc': 0, 'Time': 0.00393986701965332}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
# After solving the model
optimal_prices_storage = [model_storage.price[i].value for i in df_storage.index]
max_revenue_storage = model_storage.objective()

print("Optimal prices (Storage): ", optimal_prices_storage)
print("Maximum revenue (Storage): ", max_revenue_storage)
# Out:
# Optimal prices (Storage):  [33.0, 27.5, 55.0, 27.5, 27.5, 33.0, 0.0, 0.0, 55.0, 0.0, 0.0, 38.5, 38.5, 27.5, 22.0, 0.0, 0.0, 55.0, 44.0, 0.0, 0.0, 0.0, 27.5, 0.0, 33.0, 27.5, 0.0, 0.0, 0.0, 44.0, 22.0, 0.0, 0.0, 33.0, 55.0, 0.0, 38.5, 27.5, 27.5, 44.0]
# Maximum revenue (Storage):  50112.810000000005
